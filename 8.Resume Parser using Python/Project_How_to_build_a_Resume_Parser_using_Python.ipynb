# %%
# !pip install spacy==2.3.5
# Out:
# Collecting spacy==2.3.5
#   Downloading spacy-2.3.5.tar.gz (5.8 MB)
#      ---------------------------------------- 0.0/5.8 MB ? eta -:--:--
#      ---------------------------------------- 0.0/5.8 MB 1.4 MB/s eta 0:00:05
#      ---------------------------------------- 0.1/5.8 MB 656.4 kB/s eta 0:00:09
#       --------------------------------------- 0.1/5.8 MB 751.6 kB/s eta 0:00:08
#      - -------------------------------------- 0.2/5.8 MB 833.5 kB/s eta 0:00:07
#      - -------------------------------------- 0.2/5.8 MB 1.1 MB/s eta 0:00:05
#      -- ------------------------------------- 0.3/5.8 MB 1.2 MB/s eta 0:00:05
#      --- ------------------------------------ 0.5/5.8 MB 1.6 MB/s eta 0:00:04
#      ----- ---------------------------------- 0.8/5.8 MB 2.2 MB/s eta 0:00:03
#      ------- -------------------------------- 1.1/5.8 MB 2.6 MB/s eta 0:00:02
#      ----------- ---------------------------- 1.7/5.8 MB 3.7 MB/s eta 0:00:02
#      --------------- ------------------------ 2.2/5.8 MB 4.4 MB/s eta 0:00:01
#      -------------------- ------------------- 2.9/5.8 MB 5.3 MB/s eta 0:00:01
#      ------------------------------ --------- 4.5/5.8 MB 7.5 MB/s eta 0:00:01
#      ------------------------------------ --- 5.3/5.8 MB 8.3 MB/s eta 0:00:01
#      ---------------------------------------- 5.8/5.8 MB 8.6 MB/s eta 0:00:00
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'error'
# WARNING: Ignoring invalid distribution -rotobuf (e:\nlp\.venv310\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (e:\nlp\.venv310\lib\site-packages)
#   error: subprocess-exited-with-error
#
#   × Getting requirements to build wheel did not run successfully.
#   │ exit code: 1
#   ╰─> [15 lines of output]
#       Traceback (most recent call last):
#         File "E:\nlp\.venv310\lib\site-packages\pip\_vendor\pyproject_hooks\_in_process\_in_process.py", line 353, in <module>
#           main()
#         File "E:\nlp\.venv310\lib\site-packages\pip\_vendor\pyproject_hooks\_in_process\_in_process.py", line 335, in main
#           json_out['return_val'] = hook(**hook_input['kwargs'])
#         File "E:\nlp\.venv310\lib\site-packages\pip\_vendor\pyproject_hooks\_in_process\_in_process.py", line 118, in get_requires_for_build_wheel
#           return hook(config_settings)
#         File "C:\Users\hoang\AppData\Local\Temp\pip-build-env-yc0m7xiv\overlay\Lib\site-packages\setuptools\build_meta.py", line 333, in get_requires_for_build_wheel
#           return self._get_build_requires(config_settings, requirements=[])
#         File "C:\Users\hoang\AppData\Local\Temp\pip-build-env-yc0m7xiv\overlay\Lib\site-packages\setuptools\build_meta.py", line 301, in _get_build_requires
#           self.run_setup()
#         File "C:\Users\hoang\AppData\Local\Temp\pip-build-env-yc0m7xiv\overlay\Lib\site-packages\setuptools\build_meta.py", line 317, in run_setup
#           exec(code, locals())
#         File "<string>", line 12, in <module>
#       ImportError: cannot import name 'msvccompiler' from 'distutils' (C:\Users\hoang\AppData\Local\Temp\pip-build-env-yc0m7xiv\overlay\Lib\site-packages\setuptools\_distutils\__init__.py)
#       [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
# error: subprocess-exited-with-error
#
# × Getting requirements to build wheel did not run successfully.
# │ exit code: 1
# ╰─> See above for output.
#
# note: This error originates from a subprocess, and is likely not a problem with pip.
# WARNING: Ignoring invalid distribution -rotobuf (e:\nlp\.venv310\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (e:\nlp\.venv310\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (e:\nlp\.venv310\lib\site-packages)
#
# [notice] A new release of pip is available: 23.0.1 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# !pip install https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-2.3.1/en_core_web_sm-2.3.1.tar.gz
# Out:
# Collecting https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-2.3.1/en_core_web_sm-2.3.1.tar.gz
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-2.3.1/en_core_web_sm-2.3.1.tar.gz (12.0 MB)
#      ---------------------------------------- 0.0/12.0 MB ? eta -:--:--
#       --------------------------------------- 0.3/12.0 MB ? eta -:--:--
#      ----------- ---------------------------- 3.4/12.0 MB 13.4 MB/s eta 0:00:01
#      -------------------------- ------------- 8.1/12.0 MB 21.0 MB/s eta 0:00:01
#      ---------------------------------------- 12.0/12.0 MB 20.4 MB/s  0:00:00
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Collecting spacy<2.4.0,>=2.3.0 (from en_core_web_sm==2.3.1)
#   Using cached spacy-2.3.9.tar.gz (1.0 MB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'error'
#   error: subprocess-exited-with-error
#
#   × installing build dependencies for spacy did not run successfully.
#   │ exit code: 1
#   ╰─> [43 lines of output]
#       Collecting setuptools
#         Using cached setuptools-82.0.1-py3-none-any.whl.metadata (6.5 kB)
#       Collecting cython<3.0,>=0.25
#         Using cached Cython-0.29.37-py2.py3-none-any.whl.metadata (3.1 kB)
#       Collecting cymem<2.1.0,>=2.0.2
#         Using cached cymem-2.0.13-cp312-cp312-win_amd64.whl.metadata (9.9 kB)
#       Collecting preshed<3.1.0,>=3.0.2
#         Using cached preshed-3.0.13-cp312-cp312-win_amd64.whl.metadata (5.4 kB)
#       Collecting murmurhash<1.1.0,>=0.28.0
#         Using cached murmurhash-1.0.15-cp312-cp312-win_amd64.whl.metadata (2.3 kB)
#       Collecting thinc<7.5.0,>=7.4.1
#         Using cached thinc-7.4.6.tar.gz (1.3 MB)
#         Installing build dependencies: started
#         Installing build dependencies: finished with status 'done'
#         Getting requirements to build wheel: started
#         Getting requirements to build wheel: finished with status 'error'
#         error: subprocess-exited-with-error
#
#         Ã— Getting requirements to build wheel did not run successfully.
#         â”‚ exit code: 1
#         â•°â”€> [18 lines of output]
#             Traceback (most recent call last):
#               File "E:\nlp\.venv\Lib\site-packages\pip\_vendor\pyproject_hooks\_in_process\_in_process.py", line 389, in <module>
#                 main()
#               File "E:\nlp\.venv\Lib\site-packages\pip\_vendor\pyproject_hooks\_in_process\_in_process.py", line 373, in main
#                 json_out["return_val"] = hook(**hook_input["kwargs"])
#                                          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#               File "E:\nlp\.venv\Lib\site-packages\pip\_vendor\pyproject_hooks\_in_process\_in_process.py", line 143, in get_requires_for_build_wheel
#                 return hook(config_settings)
#                        ^^^^^^^^^^^^^^^^^^^^^
#               File "C:\Users\hoang\AppData\Local\Temp\pip-build-env-clzurnwu\overlay\Lib\site-packages\setuptools\build_meta.py", line 333, in get_requires_for_build_wheel
#                 return self._get_build_requires(config_settings, requirements=[])
#                        ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#               File "C:\Users\hoang\AppData\Local\Temp\pip-build-env-clzurnwu\overlay\Lib\site-packages\setuptools\build_meta.py", line 301, in _get_build_requires
#                 self.run_setup()
#               File "C:\Users\hoang\AppData\Local\Temp\pip-build-env-clzurnwu\overlay\Lib\site-packages\setuptools\build_meta.py", line 317, in run_setup
#                 exec(code, locals())
#               File "<string>", line 12, in <module>
#             ImportError: cannot import name 'msvccompiler' from 'distutils' (C:\Users\hoang\AppData\Local\Temp\pip-build-env-clzurnwu\overlay\Lib\site-packages\setuptools\_distutils\__init__.py). Did you mean: 'ccompiler'?
#             [end of output]
#
#         note: This error originates from a subprocess, and is likely not a problem with pip.
#       ERROR: Failed to build 'thinc' when getting requirements to build wheel
#       [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
# ERROR: Failed to build 'spacy' when installing build dependencies for spacy

# %%
# !pip install pyresparser
# Out:
# Requirement already satisfied: pyresparser in E:\nlp\.venv\Lib\site-packages (1.0.6)
# Requirement already satisfied: attrs>=19.1.0 in E:\nlp\.venv\Lib\site-packages (from pyresparser) (26.1.0)
# Requirement already satisfied: blis>=0.2.4 in E:\nlp\.venv\Lib\site-packages (from pyresparser) (1.3.3)
# Requirement already satisfied: certifi>=2019.6.16 in E:\nlp\.venv\Lib\site-packages (from pyresparser) (2026.2.25)
# Requirement already satisfied: chardet>=3.0.4 in E:\nlp\.venv\Lib\site-packages (from pyresparser) (7.4.3)
# Requirement already satisfied: cymem>=2.0.2 in E:\nlp\.venv\Lib\site-packages (from pyresparser) (2.0.13)
# Requirement already satisfied: docx2txt>=0.7 in E:\nlp\.venv\Lib\site-packages (from pyresparser) (0.9)
# Requirement already satisfied: idna>=2.8 in E:\nlp\.venv\Lib\site-packages (from pyresparser) (3.11)
# Requirement already satisfied: jsonschema>=3.0.1 in E:\nlp\.venv\Lib\site-packages (from pyresparser) (4.26.0)
# Requirement already satisfied: nltk>=3.4.3 in E:\nlp\.venv\Lib\site-packages (from pyresparser) (3.9.4)
# Requirement already satisfied: numpy>=1.16.4 in E:\nlp\.venv\Lib\site-packages (from pyresparser) (2.4.4)
# Requirement already satisfied: pandas>=0.24.2 in E:\nlp\.venv\Lib\site-packages (from pyresparser) (3.0.2)
# Requirement already satisfied: pdfminer.six>=20181108 in E:\nlp\.venv\Lib\site-packages (from pyresparser) (20260107)
# Requirement already satisfied: preshed>=2.0.1 in E:\nlp\.venv\Lib\site-packages (from pyresparser) (3.0.13)
# Requirement already satisfied: pycryptodome>=3.8.2 in E:\nlp\.venv\Lib\site-packages (from pyresparser) (3.23.0)
# Requirement already satisfied: pyrsistent>=0.15.2 in E:\nlp\.venv\Lib\site-packages (from pyresparser) (0.20.0)
# Requirement already satisfied: python-dateutil>=2.8.0 in E:\nlp\.venv\Lib\site-packages (from pyresparser) (2.9.0.post0)
# Requirement already satisfied: pytz>=2019.1 in E:\nlp\.venv\Lib\site-packages (from pyresparser) (2026.1.post1)
# Requirement already satisfied: requests>=2.22.0 in E:\nlp\.venv\Lib\site-packages (from pyresparser) (2.33.1)
# Requirement already satisfied: six>=1.12.0 in E:\nlp\.venv\Lib\site-packages (from pyresparser) (1.17.0)
# Requirement already satisfied: sortedcontainers>=2.1.0 in E:\nlp\.venv\Lib\site-packages (from pyresparser) (2.4.0)
# Collecting spacy>=2.1.4 (from pyresparser)
#   Using cached spacy-3.8.14-cp312-cp312-win_amd64.whl.metadata (28 kB)
# Requirement already satisfied: srsly>=0.0.7 in E:\nlp\.venv\Lib\site-packages (from pyresparser) (2.5.3)
# Requirement already satisfied: thinc>=7.0.4 in E:\nlp\.venv\Lib\site-packages (from pyresparser) (8.3.13)
# Requirement already satisfied: tqdm>=4.32.2 in E:\nlp\.venv\Lib\site-packages (from pyresparser) (4.67.3)
# Requirement already satisfied: urllib3>=1.25.3 in E:\nlp\.venv\Lib\site-packages (from pyresparser) (2.6.3)
# Requirement already satisfied: wasabi>=0.2.2 in E:\nlp\.venv\Lib\site-packages (from pyresparser) (1.1.3)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in E:\nlp\.venv\Lib\site-packages (from jsonschema>=3.0.1->pyresparser) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in E:\nlp\.venv\Lib\site-packages (from jsonschema>=3.0.1->pyresparser) (0.37.0)
# Requirement already satisfied: rpds-py>=0.25.0 in E:\nlp\.venv\Lib\site-packages (from jsonschema>=3.0.1->pyresparser) (0.30.0)
# Requirement already satisfied: click in E:\nlp\.venv\Lib\site-packages (from nltk>=3.4.3->pyresparser) (8.3.2)
# Requirement already satisfied: joblib in E:\nlp\.venv\Lib\site-packages (from nltk>=3.4.3->pyresparser) (1.5.3)
# Requirement already satisfied: regex>=2021.8.3 in E:\nlp\.venv\Lib\site-packages (from nltk>=3.4.3->pyresparser) (2026.4.4)
# Requirement already satisfied: tzdata in E:\nlp\.venv\Lib\site-packages (from pandas>=0.24.2->pyresparser) (2026.1)
# Requirement already satisfied: charset-normalizer>=2.0.0 in E:\nlp\.venv\Lib\site-packages (from pdfminer.six>=20181108->pyresparser) (3.4.7)
# Requirement already satisfied: cryptography>=36.0.0 in E:\nlp\.venv\Lib\site-packages (from pdfminer.six>=20181108->pyresparser) (46.0.7)
# Requirement already satisfied: cffi>=2.0.0 in E:\nlp\.venv\Lib\site-packages (from cryptography>=36.0.0->pdfminer.six>=20181108->pyresparser) (2.0.0)
# Requirement already satisfied: pycparser in E:\nlp\.venv\Lib\site-packages (from cffi>=2.0.0->cryptography>=36.0.0->pdfminer.six>=20181108->pyresparser) (3.0)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in E:\nlp\.venv\Lib\site-packages (from preshed>=2.0.1->pyresparser) (1.0.15)
# Requirement already satisfied: typing-extensions>=4.4.0 in E:\nlp\.venv\Lib\site-packages (from referencing>=0.28.4->jsonschema>=3.0.1->pyresparser) (4.15.0)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in E:\nlp\.venv\Lib\site-packages (from spacy>=2.1.4->pyresparser) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in E:\nlp\.venv\Lib\site-packages (from spacy>=2.1.4->pyresparser) (1.0.5)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in E:\nlp\.venv\Lib\site-packages (from spacy>=2.1.4->pyresparser) (2.0.10)
# Requirement already satisfied: weasel<2.0.0,>=1.0.0 in E:\nlp\.venv\Lib\site-packages (from spacy>=2.1.4->pyresparser) (1.0.0)
# Requirement already satisfied: confection<2.0.0,>=1.3.2 in E:\nlp\.venv\Lib\site-packages (from spacy>=2.1.4->pyresparser) (1.3.3)
# Requirement already satisfied: typer<1.0.0,>=0.3.0 in E:\nlp\.venv\Lib\site-packages (from spacy>=2.1.4->pyresparser) (0.24.1)
# Requirement already satisfied: pydantic<3.0.0,>=2.0.0 in E:\nlp\.venv\Lib\site-packages (from spacy>=2.1.4->pyresparser) (2.13.1)
# Requirement already satisfied: jinja2 in E:\nlp\.venv\Lib\site-packages (from spacy>=2.1.4->pyresparser) (3.1.6)
# Requirement already satisfied: setuptools in E:\nlp\.venv\Lib\site-packages (from spacy>=2.1.4->pyresparser) (82.0.1)
# Requirement already satisfied: packaging>=20.0 in E:\nlp\.venv\Lib\site-packages (from spacy>=2.1.4->pyresparser) (26.1)
# Requirement already satisfied: annotated-types>=0.6.0 in E:\nlp\.venv\Lib\site-packages (from pydantic<3.0.0,>=2.0.0->spacy>=2.1.4->pyresparser) (0.7.0)
# Requirement already satisfied: pydantic-core==2.46.1 in E:\nlp\.venv\Lib\site-packages (from pydantic<3.0.0,>=2.0.0->spacy>=2.1.4->pyresparser) (2.46.1)
# Requirement already satisfied: typing-inspection>=0.4.2 in E:\nlp\.venv\Lib\site-packages (from pydantic<3.0.0,>=2.0.0->spacy>=2.1.4->pyresparser) (0.4.2)
# Requirement already satisfied: colorama in E:\nlp\.venv\Lib\site-packages (from tqdm>=4.32.2->pyresparser) (0.4.6)
# Requirement already satisfied: shellingham>=1.3.0 in E:\nlp\.venv\Lib\site-packages (from typer<1.0.0,>=0.3.0->spacy>=2.1.4->pyresparser) (1.5.4)
# Requirement already satisfied: rich>=12.3.0 in E:\nlp\.venv\Lib\site-packages (from typer<1.0.0,>=0.3.0->spacy>=2.1.4->pyresparser) (15.0.0)
# Requirement already satisfied: annotated-doc>=0.0.2 in E:\nlp\.venv\Lib\site-packages (from typer<1.0.0,>=0.3.0->spacy>=2.1.4->pyresparser) (0.0.4)
# Requirement already satisfied: cloudpathlib>=0.7.0 in E:\nlp\.venv\Lib\site-packages (from weasel<2.0.0,>=1.0.0->spacy>=2.1.4->pyresparser) (0.23.0)
# Requirement already satisfied: smart-open>=5.2.1 in E:\nlp\.venv\Lib\site-packages (from weasel<2.0.0,>=1.0.0->spacy>=2.1.4->pyresparser) (7.6.0)
# Requirement already satisfied: httpx>=0.24.0 in E:\nlp\.venv\Lib\site-packages (from weasel<2.0.0,>=1.0.0->spacy>=2.1.4->pyresparser) (0.28.1)
# Requirement already satisfied: anyio in E:\nlp\.venv\Lib\site-packages (from httpx>=0.24.0->weasel<2.0.0,>=1.0.0->spacy>=2.1.4->pyresparser) (4.13.0)
# Requirement already satisfied: httpcore==1.* in E:\nlp\.venv\Lib\site-packages (from httpx>=0.24.0->weasel<2.0.0,>=1.0.0->spacy>=2.1.4->pyresparser) (1.0.9)
# Requirement already satisfied: h11>=0.16 in E:\nlp\.venv\Lib\site-packages (from httpcore==1.*->httpx>=0.24.0->weasel<2.0.0,>=1.0.0->spacy>=2.1.4->pyresparser) (0.16.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in E:\nlp\.venv\Lib\site-packages (from rich>=12.3.0->typer<1.0.0,>=0.3.0->spacy>=2.1.4->pyresparser) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in E:\nlp\.venv\Lib\site-packages (from rich>=12.3.0->typer<1.0.0,>=0.3.0->spacy>=2.1.4->pyresparser) (2.20.0)
# Requirement already satisfied: mdurl~=0.1 in E:\nlp\.venv\Lib\site-packages (from markdown-it-py>=2.2.0->rich>=12.3.0->typer<1.0.0,>=0.3.0->spacy>=2.1.4->pyresparser) (0.1.2)
# Requirement already satisfied: wrapt in E:\nlp\.venv\Lib\site-packages (from smart-open>=5.2.1->weasel<2.0.0,>=1.0.0->spacy>=2.1.4->pyresparser) (2.1.2)
# Requirement already satisfied: MarkupSafe>=2.0 in E:\nlp\.venv\Lib\site-packages (from jinja2->spacy>=2.1.4->pyresparser) (3.0.3)
# Using cached spacy-3.8.14-cp312-cp312-win_amd64.whl (14.2 MB)
# Installing collected packages: spacy
# Successfully installed spacy-3.8.14

# %%
import nltk
nltk.download('stopwords')

from pyresparser import ResumeParser
import warnings
warnings.filterwarnings("ignore", category=UserWarning)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 import nltk
#       2 nltk.download('stopwords')
#       4 from pyresparser import ResumeParser
#
# ModuleNotFoundError: No module named 'nltk'

# %%
warnings.filterwarnings("ignore", category=UserWarning)

# %%
from pyresparser import ResumeParser
data = ResumeParser("resume.pdf").get_extracted_data()

# %%
print("Name:", data["name"])
print("Email:", data["email"])
print("Mobile Number:", data["mobile_number"])
print("Skills:", data["skills"])
print("College Name:", data["college_name"])
print("Degree:", data["degree"])
print("Designation:", data["designation"])
print("Company Names:", data["company_names"])
print("No Of Pages:", data["no_of_pages"])
print("Total Experience:", data["total_experience"])

# %%
from pyresparser import ResumeParser
import warnings

warnings.filterwarnings("ignore", category=UserWarning)

data = ResumeParser("resume.pdf").get_extracted_data()

print("Name:", data["name"])
print("Email:", data["email"])
print("Mobile Number:", data["mobile_number"])
print("Skills:", data["skills"])
print("College Name:", data["college_name"])
print("Degree:", data["degree"])
print("Designation:", data["designation"])
print("Company Names:", data["company_names"])
print("No Of Pages:", data["no_of_pages"])
print("Total Experience:", data["total_experience"])
